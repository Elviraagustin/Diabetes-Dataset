# %% [markdown]
# <a href="https://colab.research.google.com/github/Elviraagustin/Diabetes-Dataset/blob/main/Chechkpoint3.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# Nama : Elvira agustin
#
# NIM  : 2409116109

# %% [markdown]
# # **Studi Kasus : Mengidentifikasi Faktor Risiko Diabetes Melalui Analisis Dataset**

# %% [markdown]
# **Latar Belakang**
#
# penggunaan dataset diabetes ini berkaitan dengan meningkatnya prevalensi diabetes di seluruh dunia, yang telah menjadi salah satu tantangan kesehatan masyarakat yang paling mendesak terkait dengan faktor gaya hidup seperti pola makan yang tidak sehat, kurangnya aktivitas fisik, dan obesitas. Jumlah orang yang menderita diabetes telah meningkat secara signifikan dalam beberapa dekade terakhir, dan diperkirakan akan terus meningkat jika tidak ada intervensi yang efektif. Secara keseluruhan, latar belakang ini menekankan pentingnya pemanfaatan data dalam upaya untuk memahami dan mengatasi diabetes, serta menciptakan dampak positif bagi kesehatan individu dan masyarakat.

# %% [markdown]
# **Tujuan Studi Kasus**
#
# Tujuan utama dari analisis ini adalah:
# 1. Diagnosis dini yang memungkinkan profesional kesehatan untuk melakukan diagnosis menggunakan data yang relevan.
# 2. enelitian Kesehatan yang menyediakan data untuk penelitian lebih lanjut mengenai faktor-faktor yang berkontribusi terhadap diabetes.
# 3. Pengembangan Model Prediktif yang memfasilitasi pengembangan dan pengujian model pembelajaran.
# 4. Peningkatan Kesadaran yang meningkatkan kesadaran tentang pentingnya faktor-faktor risiko diabetes

# %% [markdown]
# **Analisis**
#
# Analisis dataset diabetes dapat dilakukan dengan eksplorasi data menggunakan pyton dan pustaka pandas.
#
# 1. Menghitung Jumlah nilai unik dalam kolom untuk melihat riwayat penyakit dan riwayat merokok
# 2. Analisis Korelasi: untuk menghitung korelasi dan visualisasi.
# 3. Visualisasi Data: untuk membuat grafik distribusi dan visualisasi yang lebih kompleks.
# 4. Statistik deskriptif: Menghitung rata-rata, menghitung median untuk mengetahui nilai tengah, menghitung standar deviasi untuk memahami variasi kunjungan dari hari ke hari.

# %% [markdown]
# # **Business Understanding**

# %% [markdown]
# ### **Business Objective**
#
# Penggunaan dataset diabetes ini adalah untuk mengembangkan solusi berbasis data yang dapat meningkatkan diagnosis dan pengelolaan diabetes, sehingga berkontribusi pada peningkatan kesehatan masyarakat. menciptakan model prediktif yang akurat untuk mengidentifikasi individu yang berisiko tinggi menderita diabetes. Hal ini tidak hanya akan membantu profesional kesehatan dalam melakukan diagnosis dini, tetapi juga memungkinkan pengembangan program pencegahan yang lebih efektif. Selain itu, dengan memahami faktor-faktor risiko yang berkontribusi terhadap diabetes melalui analisis data, organisasi kesehatan dapat merancang intervensi yang lebih terarah dan berbasis bukti.

# %% [markdown]
# ### **Assess Situation**
#
# Diabetes merupakan salah satu masalah kesehatan global yang semakin meningkat. Menurut Organisasi Kesehatan Dunia (WHO), jumlah penderita diabetes terus meningkat, dan penyakit ini dapat menyebabkan berbagai komplikasi serius, termasuk penyakit jantung, kerusakan saraf, dan masalah penglihatan. Oleh karena itu, penting untuk memiliki alat yang efektif untuk mendiagnosis dan mengelola penyakit ini. Banyak individu yang menderita diabetes tidak menyadari kondisi mereka, yang dapat mengakibatkan keterlambatan dalam pengobatan dan peningkatan risiko komplikasi. Dengan menggunakan dataset ini, profesional kesehatan dapat mengembangkan model yang membantu dalam diagnosis dini, sehingga pasien dapat menerima perawatan yang diperlukan lebih cepat.

# %% [markdown]
# ### **Data Mining Goals**
#
# Data mining adalah proses menemukan pola, tren, dan informasi berguna dari kumpulan data besar dengan menggunakan teknik statistik, algoritma pembelajaran mesin, dan analisis data. Dengan menerapkan teknik-teknik data mining ini, peneliti dan profesional kesehatan dapat memperoleh wawasan yang lebih dalam tentang diabetes, mengidentifikasi faktor risiko, dan mengembangkan model yang dapat membantu dalam diagnosis dan pengelolaan penyakit.

# %% [markdown]
# ### **Project Plan**
#
# Untuk memahami dataset ini, langkah pertama adalah menampilkan data yang tersedia untuk mendapatkan gambaran awal. Setelah itu, beberapa langkah akan dilakukan untuk menganalisis Diabetes.

# %% [markdown]
# ## **Tampilan data secara keseluruhan**

# %%
import pandas as pd

# %%
df = pd.read_csv('/content/diabetes_prediction_dataset.csv.zip')
print(df)
# Out:
#        gender   age  hypertension  heart_disease smoking_history    bmi  \
# 0      Female  80.0             0              1           never  25.19
# 1      Female  54.0             0              0         No Info  27.32
# 2        Male  28.0             0              0           never  27.32
# 3      Female  36.0             0              0         current  23.45
# 4        Male  76.0             1              1         current  20.14
# ...       ...   ...           ...            ...             ...    ...
# 99995  Female  80.0             0              0         No Info  27.32
# 99996  Female   2.0             0              0         No Info  17.37
# 99997    Male  66.0             0              0          former  27.83
# 99998  Female  24.0             0              0           never  35.42
# 99999  Female  57.0             0              0         current  22.43
#
#        HbA1c_level  blood_glucose_level  diabetes
# 0              6.6                  140         0
# 1              6.6                   80         0
# 2              5.7                  158         0
# 3              5.0                  155         0
# 4              4.8                  155         0
# ...            ...                  ...       ...
# 99995          6.2                   90         0
# 99996          6.5                  100         0
# 99997          5.7                  155         0
# 99998          4.0                  100         0
# 99999          6.6                   90         0
#
# [100000 rows x 9 columns]

# %% [markdown]
# ### **Tampilan 5 baris pertama data**

# %%
df.head()
# Out:
#    gender   age  hypertension  heart_disease smoking_history    bmi  \
# 0  Female  80.0             0              1           never  25.19
# 1  Female  54.0             0              0         No Info  27.32
# 2    Male  28.0             0              0           never  27.32
# 3  Female  36.0             0              0         current  23.45
# 4    Male  76.0             1              1         current  20.14
#
#    HbA1c_level  blood_glucose_level  diabetes
# 0          6.6                  140         0
# 1          6.6                   80         0
# 2          5.7                  158         0
# 3          5.0                  155         0
# 4          4.8                  155         0

# %% [markdown]
# ## **Info Data**

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 100000 entries, 0 to 99999
# Data columns (total 9 columns):
#  #   Column               Non-Null Count   Dtype
# ---  ------               --------------   -----
#  0   gender               100000 non-null  object
#  1   age                  100000 non-null  float64
#  2   hypertension         100000 non-null  int64
#  3   heart_disease        100000 non-null  int64
#  4   smoking_history      100000 non-null  object
#  5   bmi                  100000 non-null  float64
#  6   HbA1c_level          100000 non-null  float64
#  7   blood_glucose_level  100000 non-null  int64
#  8   diabetes             100000 non-null  int64
# dtypes: float64(3), int64(4), object(2)
# memory usage: 6.9+ MB

# %% [markdown]
# ### **1. Menghitung Hipertensi dan Riwayat Merokok Pada Penderita Diabetes**

# %%
kolom_tertentu = "hypertension"
if kolom_tertentu in df.columns:
    print(f"\nMenghitung jumlah kemunculan nilai unik dalam kolom '{kolom_tertentu}' dengan df['{kolom_tertentu}'].value_counts():")
    print(df[kolom_tertentu].value_counts())
else:
    print(f"\nKolom '{kolom_tertentu}' tidak ditemukan dalam dataset.")
# Out:
# Menghitung jumlah kemunculan nilai unik dalam kolom 'hypertension' dengan df['hypertension'].value_counts():
# hypertension
# 0    92515
# 1     7485
# Name: count, dtype: int64

# %%
kolom_tertentu = "smoking_history"
if kolom_tertentu in df.columns:
    print(f"\nMenghitung jumlah kemunculan nilai unik dalam kolom '{kolom_tertentu}' dengan df['{kolom_tertentu}'].value_counts():")
    print(df[kolom_tertentu].value_counts())
else:
    print(f"\nKolom '{kolom_tertentu}' tidak ditemukan dalam dataset.")
# Out:
# Menghitung jumlah kemunculan nilai unik dalam kolom 'smoking_history' dengan df['smoking_history'].value_counts():
# smoking_history
# No Info        35816
# never          35095
# former          9352
# current         9286
# not current     6447
# ever            4004
# Name: count, dtype: int64

# %% [markdown]
# hypertension : Dari total data yang dianalisis, terdapat 92.515 individu yang tidak memiliki hipertensi (nilai 0), sementara 7.485 individu lainnya terdiagnosis hipertensi (nilai 1).
#
#
# smoking history : Dari total data yang diperoleh, terdapat 35.816 individu yang tidak memiliki informasi mengenai riwayat merokok (kategori "No Info"). Selain itu, 35.095 individu dilaporkan tidak pernah merokok (kategori "never"), sementara 9.352 individu adalah mantan perokok (kategori "former").

# %% [markdown]
# ### **2.Menghitung Rata-Rata**

# %%
print("\nMenghitung rata-rata dengan df.mean():")
print(df.mean(numeric_only=True))
# Out:
# Menghitung rata-rata dengan df.mean():
# age                     41.885856
# hypertension             0.074850
# heart_disease            0.039420
# bmi                     27.320767
# HbA1c_level              5.527507
# blood_glucose_level    138.058060
# diabetes                 0.085000
# dtype: float64

# %% [markdown]
# ### **3.Menghitung median**

# %%
print("\nMenghitung median dengan df.median():")
print(df.median(numeric_only=True))
# Out:
# Menghitung median dengan df.median():
# age                     43.00
# hypertension             0.00
# heart_disease            0.00
# bmi                     27.32
# HbA1c_level              5.80
# blood_glucose_level    140.00
# diabetes                 0.00
# dtype: float64

# %% [markdown]
# Secara keseluruhan, analisis median ini memberikan gambaran yang jelas tentang karakteristik demografis dan kesehatan dari populasi yang dianalisis

# %%
print("\nMenghitung standar deviasi dengan df.std():")
print(df.std(numeric_only=True))
# Out:
# Menghitung standar deviasi dengan df.std():
# age                    22.516840
# hypertension            0.263150
# heart_disease           0.194593
# bmi                     6.636783
# HbA1c_level             1.070672
# blood_glucose_level    40.708136
# diabetes                0.278883
# dtype: float64

# %% [markdown]
# Membantu dalam mengidentifikasi kelompok individu yang mungkin memiliki risiko lebih tinggi untuk kondisi kesehatan tertentu, termasuk diabetes. Variabilitas yang tinggi dalam beberapa variabel, seperti usia, BMI, dan kadar glukosa darah, menunjukkan perlunya pendekatan yang lebih terfokus dalam intervensi kesehatan dan pencegahan.

# %% [markdown]
# ### **4.Menghitung Kolerasi**

# %%
print("\nMenghitung korelasi antar kolom numerik dengan df.corr():")
print(df.corr(numeric_only=True))
# Out:
# Menghitung korelasi antar kolom numerik dengan df.corr():
#                           age  hypertension  heart_disease       bmi  \
# age                  1.000000      0.251171       0.233354  0.337396
# hypertension         0.251171      1.000000       0.121262  0.147666
# heart_disease        0.233354      0.121262       1.000000  0.061198
# bmi                  0.337396      0.147666       0.061198  1.000000
# HbA1c_level          0.101354      0.080939       0.067589  0.082997
# blood_glucose_level  0.110672      0.084429       0.070066  0.091261
# diabetes             0.258008      0.197823       0.171727  0.214357
#
#                      HbA1c_level  blood_glucose_level  diabetes
# age                     0.101354             0.110672  0.258008
# hypertension            0.080939             0.084429  0.197823
# heart_disease           0.067589             0.070066  0.171727
# bmi                     0.082997             0.091261  0.214357
# HbA1c_level             1.000000             0.166733  0.400660
# blood_glucose_level     0.166733             1.000000  0.419558
# diabetes                0.400660             0.419558  1.000000

# %% [markdown]
# Korelasi ini memberikan wawasan yang berharga tentang hubungan antara berbagai faktor risiko dan diabetes. Kadar glukosa darah dan HbA1c muncul sebagai indikator yang paling kuat untuk memprediksi diabetes, diikuti oleh usia, hipertensi, dan BMI.

# %% [markdown]
# ### **6.Visualisasi Data**

# %%
import matplotlib.pyplot as plt
import seaborn as sns

# %%
plt.figure(figsize=(8, 5))
sns.countplot(x='diabetes', data=df)
plt.title('Jumlah Individu Berdasarkan Status Diabetes')
plt.xlabel('Status Diabetes (0 = Tidak, 1 = Ya)')
plt.ylabel('Jumlah Individu')
plt.xticks(ticks=[0, 1], labels=['Tidak', 'Ya'])
plt.show()

# %% [markdown]
# Jumlah individu berdasarkan status diabetes yang tidak mengalami riwayat diabetes lebih tinggi dibandingkan dengan yang memiliki riwayat penyakit diabetes..

# %% [markdown]
# ### **Kesimpulan**
#
# Analisis ini memberikan wawasan yang berharga tentang faktor-faktor yang berkontribusi terhadap diabetes dan dapat membantu dalam pengembangan strategi pencegahan dan pengelolaan yang lebih efektif.

# %% [markdown]
# # **Data Understanding**

# %% [markdown]
# ## **Sumber Data**
#
# Dataset yang digunakan dalam analisis ini adalah " Diabetes Prediction Dataset" yang diperoleh dari Kaggle. Dataset ini berisi informasi mengenai banyaknya yang menderita penyakit diabetes, riwayat perokok, hipertensi, dan hal lainnya.
#
# sumber Dataset : https://www.kaggle.com/datasets/akshaydattatraykhare/diabetes-dataset

# %% [markdown]
# ## **Struktur Data**
#
# Dataset ini berisi informasi tentang pasien diabetes dan memiliki beberapa kolom. Berikut adalah struktur data dari dataset tersebut:
#
# Pregnancies: Jumlah kehamilan yang dialami pasien.
#
# Glucose: Kadar glukosa dalam darah (mg/dL) pada saat pemeriksaan.
#
# smoking_history: Riwayat Perokok.
#
# BloodPressure: Tekanan darah diastolik (mm Hg).
#
# hypertension: Yang mengalami Hipertensi.
#
# Insulin: Kadar insulin dalam darah (mu U/ml).
#
# BMI: Indeks massa tubuh (kg/m²).
#
# DiabetesPedigreeFunction: Skor yang menunjukkan riwayat diabetes dalam keluarga.
#
# Age: Usia pasien (tahun).
#
# Outcome: Status diabetes (0 = tidak diabetes, 1 = diabetes).

# %% [markdown]
# # **Informasi Data**

# %%
import pandas as pd

# %%
df = pd.read_csv("/content/diabetes_prediction_dataset.csv.zip")
print(df)
# Out:
#        gender   age  hypertension  heart_disease smoking_history    bmi  \
# 0      Female  80.0             0              1           never  25.19
# 1      Female  54.0             0              0         No Info  27.32
# 2        Male  28.0             0              0           never  27.32
# 3      Female  36.0             0              0         current  23.45
# 4        Male  76.0             1              1         current  20.14
# ...       ...   ...           ...            ...             ...    ...
# 99995  Female  80.0             0              0         No Info  27.32
# 99996  Female   2.0             0              0         No Info  17.37
# 99997    Male  66.0             0              0          former  27.83
# 99998  Female  24.0             0              0           never  35.42
# 99999  Female  57.0             0              0         current  22.43
#
#        HbA1c_level  blood_glucose_level  diabetes
# 0              6.6                  140         0
# 1              6.6                   80         0
# 2              5.7                  158         0
# 3              5.0                  155         0
# 4              4.8                  155         0
# ...            ...                  ...       ...
# 99995          6.2                   90         0
# 99996          6.5                  100         0
# 99997          5.7                  155         0
# 99998          4.0                  100         0
# 99999          6.6                   90         0
#
# [100000 rows x 9 columns]

# %% [markdown]
# # **Missing Values**
#
# Melakukan pengecekan missing values perkolom dalam bentuk presentase, guna mendukung pengambilan keputusan pada nilai yang kosong

# %%
print((df.isna().sum() / len(df)) * 100)
# Out:
# gender                 0.0
# age                    0.0
# hypertension           0.0
# heart_disease          0.0
# smoking_history        0.0
# bmi                    0.0
# HbA1c_level            0.0
# blood_glucose_level    0.0
# diabetes               0.0
# dtype: float64

# %% [markdown]
# ## **Dikarenakan nilai tidak ada yang kosong/Missing Values, maka tidak dilakukan pengecekkan nilai kosong dan tidak ada tindakan untuk mengatasi nilai kosong/Missing Values**

# %% [markdown]
# # **Duplicated Values**
#
# Duplicated Values merupakan sebuah kondisi dimana data yang muncul beberapa kali dalam satu dataset.

# %%
df[df.duplicated()]
# Out:
#        gender   age  hypertension  heart_disease smoking_history    bmi  \
# 2756     Male  80.0             0              0         No Info  27.32
# 3272   Female  80.0             0              0         No Info  27.32
# 3418   Female  19.0             0              0         No Info  27.32
# 3939   Female  78.0             1              0          former  27.32
# 3960     Male  47.0             0              0         No Info  27.32
# ...       ...   ...           ...            ...             ...    ...
# 99980  Female  52.0             0              0           never  27.32
# 99985    Male  25.0             0              0         No Info  27.32
# 99989  Female  26.0             0              0         No Info  27.32
# 99990    Male  39.0             0              0         No Info  27.32
# 99995  Female  80.0             0              0         No Info  27.32
#
#        HbA1c_level  blood_glucose_level  diabetes
# 2756           6.6                  159         0
# 3272           3.5                   80         0
# 3418           6.5                  100         0
# 3939           3.5                  130         0
# 3960           6.0                  200         0
# ...            ...                  ...       ...
# 99980          6.1                  145         0
# 99985          5.8                  145         0
# 99989          5.0                  158         0
# 99990          6.1                  100         0
# 99995          6.2                   90         0
#
# [3854 rows x 9 columns]

# %%
df = df.drop_duplicates()

# %%
df
# Out:
#        gender   age  hypertension  heart_disease smoking_history    bmi  \
# 0      Female  80.0             0              1           never  25.19
# 1      Female  54.0             0              0         No Info  27.32
# 2        Male  28.0             0              0           never  27.32
# 3      Female  36.0             0              0         current  23.45
# 4        Male  76.0             1              1         current  20.14
# ...       ...   ...           ...            ...             ...    ...
# 99994  Female  36.0             0              0         No Info  24.60
# 99996  Female   2.0             0              0         No Info  17.37
# 99997    Male  66.0             0              0          former  27.83
# 99998  Female  24.0             0              0           never  35.42
# 99999  Female  57.0             0              0         current  22.43
#
#        HbA1c_level  blood_glucose_level  diabetes
# 0              6.6                  140         0
# 1              6.6                   80         0
# 2              5.7                  158         0
# 3              5.0                  155         0
# 4              4.8                  155         0
# ...            ...                  ...       ...
# 99994          4.8                  145         0
# 99996          6.5                  100         0
# 99997          5.7                  155         0
# 99998          4.0                  100         0
# 99999          6.6                   90         0
#
# [96146 rows x 9 columns]

# %% [markdown]
# # **Melakukan imputasi**

# %%
results = []

cols = df.select_dtypes(include=['float64', 'int64']).columns

for col in cols:
    q1 = df[col].quantile(0.25)
    q3 = df[col].quantile(0.75)
    iqr = q3 - q1
    lower_bound = q1 - 1.5 * iqr
    upper_bound = q3 + 1.5 * iqr
    outliers = df[(df[col] < lower_bound) | (df[col] > upper_bound)]
    percent_outliers = (len(outliers) / len(df)) * 100
    results.append({'Kolom': col, 'Persentase Outliers': percent_outliers})

results_df = pd.DataFrame(results)
results_df.set_index('Kolom', inplace=True)
results_df = results_df.rename_axis(None, axis=0).rename_axis('Kolom', axis=1)

print(results_df)
# Out:
# Kolom                Persentase Outliers
# age                             0.000000
# hypertension                    7.760073
# heart_disease                   4.080253
# bmi                             5.568614
# HbA1c_level                     1.364591
# blood_glucose_level             2.112412
# diabetes                        8.822000

# %%
df
# Out:
#        gender   age  hypertension  heart_disease smoking_history    bmi  \
# 0      Female  80.0             0              1           never  25.19
# 1      Female  54.0             0              0         No Info  27.32
# 2        Male  28.0             0              0           never  27.32
# 3      Female  36.0             0              0         current  23.45
# 4        Male  76.0             1              1         current  20.14
# ...       ...   ...           ...            ...             ...    ...
# 99994  Female  36.0             0              0         No Info  24.60
# 99996  Female   2.0             0              0         No Info  17.37
# 99997    Male  66.0             0              0          former  27.83
# 99998  Female  24.0             0              0           never  35.42
# 99999  Female  57.0             0              0         current  22.43
#
#        HbA1c_level  blood_glucose_level  diabetes
# 0              6.6                  140         0
# 1              6.6                   80         0
# 2              5.7                  158         0
# 3              5.0                  155         0
# 4              4.8                  155         0
# ...            ...                  ...       ...
# 99994          4.8                  145         0
# 99996          6.5                  100         0
# 99997          5.7                  155         0
# 99998          4.0                  100         0
# 99999          6.6                   90         0
#
# [96146 rows x 9 columns]

# %% [markdown]
# # **Inconsistent Values**

# %%
df
# Out:
#        gender   age  hypertension  heart_disease smoking_history    bmi  \
# 0      Female  80.0             0              1           never  25.19
# 1      Female  54.0             0              0         No Info  27.32
# 2        Male  28.0             0              0           never  27.32
# 3      Female  36.0             0              0         current  23.45
# 4        Male  76.0             1              1         current  20.14
# ...       ...   ...           ...            ...             ...    ...
# 99994  Female  36.0             0              0         No Info  24.60
# 99996  Female   2.0             0              0         No Info  17.37
# 99997    Male  66.0             0              0          former  27.83
# 99998  Female  24.0             0              0           never  35.42
# 99999  Female  57.0             0              0         current  22.43
#
#        HbA1c_level  blood_glucose_level  diabetes
# 0              6.6                  140         0
# 1              6.6                   80         0
# 2              5.7                  158         0
# 3              5.0                  155         0
# 4              4.8                  155         0
# ...            ...                  ...       ...
# 99994          4.8                  145         0
# 99996          6.5                  100         0
# 99997          5.7                  155         0
# 99998          4.0                  100         0
# 99999          6.6                   90         0
#
# [96146 rows x 9 columns]

# %%
print("Nama kolom dalam DataFrame:")
print(df.columns.tolist())
print("\n")
# Out:
# Nama kolom dalam DataFrame:
# ['gender', 'age', 'hypertension', 'heart_disease', 'smoking_history', 'bmi', 'HbA1c_level', 'blood_glucose_level', 'diabetes']

# %%
columns_to_check = ["gender", "age", "bmi", "HbA1c_level", "diabetes"]

# Mencetak nilai unik untuk setiap kolom
for col in columns_to_check:
    print(f"Nilai unik dalam {col}:")
    print(df[col].unique())
    print("\n")
# Out:
# Nilai unik dalam gender:
# ['Female' 'Male' 'Other']
#
#
# Nilai unik dalam age:
# [80.   54.   28.   36.   76.   20.   44.   79.   42.   32.   53.   78.
#  67.   15.   37.   40.    5.   69.   72.    4.   30.   45.   43.   50.
#  41.   26.   34.   73.   77.   66.   29.   60.   38.    3.   57.   74.
#  19.   46.   21.   59.   27.   13.   56.    2.    7.   11.    6.   55.
#   9.   62.   47.   12.   68.   75.   22.   58.   18.   24.   17.   25.
#   0.08 33.   16.   61.   31.    8.   49.   39.   65.   14.   70.    0.56
#  48.   51.   71.    0.88 64.   63.   52.    0.16 10.   35.   23.    0.64
#   1.16  1.64  0.72  1.88  1.32  0.8   1.24  1.    1.8   0.48  1.56  1.08
#   0.24  1.4   0.4   0.32  1.72  1.48]
#
#
# Nilai unik dalam bmi:
# [25.19 27.32 23.45 ... 59.42 44.39 60.52]
#
#
# Nilai unik dalam HbA1c_level:
# [6.6 5.7 5.  4.8 6.5 6.1 6.  5.8 3.5 6.2 4.  4.5 9.  7.  8.8 8.2 7.5 6.8]
#
#
# Nilai unik dalam diabetes:
# [0 1]

# %%
df["hypertension"] = df["hypertension"].astype(str)
df["hypertension"] = df["hypertension"].str.lower().str.strip()
df["hypertension"] = df["hypertension"].str.replace(r'[^a-z0-9\s]', '', regex=True)
df["hypertension"] = df["hypertension"].str.title()

# %%
df
# Out:
#        gender   age hypertension  heart_disease smoking_history    bmi  \
# 0      Female  80.0            0              1           never  25.19
# 1      Female  54.0            0              0         No Info  27.32
# 2        Male  28.0            0              0           never  27.32
# 3      Female  36.0            0              0         current  23.45
# 4        Male  76.0            1              1         current  20.14
# ...       ...   ...          ...            ...             ...    ...
# 99994  Female  36.0            0              0         No Info  24.60
# 99996  Female   2.0            0              0         No Info  17.37
# 99997    Male  66.0            0              0          former  27.83
# 99998  Female  24.0            0              0           never  35.42
# 99999  Female  57.0            0              0         current  22.43
#
#        HbA1c_level  blood_glucose_level  diabetes
# 0              6.6                  140         0
# 1              6.6                   80         0
# 2              5.7                  158         0
# 3              5.0                  155         0
# 4              4.8                  155         0
# ...            ...                  ...       ...
# 99994          4.8                  145         0
# 99996          6.5                  100         0
# 99997          5.7                  155         0
# 99998          4.0                  100         0
# 99999          6.6                   90         0
#
# [96146 rows x 9 columns]

# %% [markdown]
# # **Construct Data**

# %%
def categorize_shade(h):
    if 0 <= h < 50 or h > 330:
        return "Warm"
    elif 50 <= h < 180:
        return "Cool"
    else:
        return "Neutral"

# %%
df["Shade_Category"] = df["bmi"].apply(categorize_shade)

# %%
df["Brightness_Ratio"] = df["HbA1c_level"] / 100

# %%
df["Contrast_Score"] = abs(df["blood_glucose_level"] - df["diabetes"])

# %%
print(df.head())
# Out:
#    gender   age hypertension  heart_disease smoking_history    bmi  \
# 0  Female  80.0            0              1           never  25.19
# 1  Female  54.0            0              0         No Info  27.32
# 2    Male  28.0            0              0           never  27.32
# 3  Female  36.0            0              0         current  23.45
# 4    Male  76.0            1              1         current  20.14
#
#    HbA1c_level  blood_glucose_level  diabetes Shade_Category  \
# 0          6.6                  140         0           Warm
# 1          6.6                   80         0           Warm
# 2          5.7                  158         0           Warm
# 3          5.0                  155         0           Warm
# 4          4.8                  155         0           Warm
#
#    Brightness_Ratio  Contrast_Score
# 0             0.066             140
# 1             0.066              80
# 2             0.057             158
# 3             0.050             155
# 4             0.048             155

# %% [markdown]
# # **Data Reduction**

# %%
df = df.drop(["gender", "age"], axis=1)

# %%
df
# Out:
#       hypertension  heart_disease smoking_history    bmi  HbA1c_level  \
# 0                0              1           never  25.19          6.6
# 1                0              0         No Info  27.32          6.6
# 2                0              0           never  27.32          5.7
# 3                0              0         current  23.45          5.0
# 4                1              1         current  20.14          4.8
# ...            ...            ...             ...    ...          ...
# 99994            0              0         No Info  24.60          4.8
# 99996            0              0         No Info  17.37          6.5
# 99997            0              0          former  27.83          5.7
# 99998            0              0           never  35.42          4.0
# 99999            0              0         current  22.43          6.6
#
#        blood_glucose_level  diabetes Shade_Category  Brightness_Ratio  \
# 0                      140         0           Warm             0.066
# 1                       80         0           Warm             0.066
# 2                      158         0           Warm             0.057
# 3                      155         0           Warm             0.050
# 4                      155         0           Warm             0.048
# ...                    ...       ...            ...               ...
# 99994                  145         0           Warm             0.048
# 99996                  100         0           Warm             0.065
# 99997                  155         0           Warm             0.057
# 99998                  100         0           Warm             0.040
# 99999                   90         0           Warm             0.066
#
#        Contrast_Score
# 0                 140
# 1                  80
# 2                 158
# 3                 155
# 4                 155
# ...               ...
# 99994             145
# 99996             100
# 99997             155
# 99998             100
# 99999              90
#
# [96146 rows x 10 columns]

# %% [markdown]
# # **Visualisasi**

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
df = pd.read_csv('/content/diabetes_prediction_dataset.csv.zip')
print(df)
# Out:
#        gender   age  hypertension  heart_disease smoking_history    bmi  \
# 0      Female  80.0             0              1           never  25.19
# 1      Female  54.0             0              0         No Info  27.32
# 2        Male  28.0             0              0           never  27.32
# 3      Female  36.0             0              0         current  23.45
# 4        Male  76.0             1              1         current  20.14
# ...       ...   ...           ...            ...             ...    ...
# 99995  Female  80.0             0              0         No Info  27.32
# 99996  Female   2.0             0              0         No Info  17.37
# 99997    Male  66.0             0              0          former  27.83
# 99998  Female  24.0             0              0           never  35.42
# 99999  Female  57.0             0              0         current  22.43
#
#        HbA1c_level  blood_glucose_level  diabetes
# 0              6.6                  140         0
# 1              6.6                   80         0
# 2              5.7                  158         0
# 3              5.0                  155         0
# 4              4.8                  155         0
# ...            ...                  ...       ...
# 99995          6.2                   90         0
# 99996          6.5                  100         0
# 99997          5.7                  155         0
# 99998          4.0                  100         0
# 99999          6.6                   90         0
#
# [100000 rows x 9 columns]

# %% [markdown]
# ## **Bar Chart**

# %%
plt.figure(figsize=(8, 5))
sns.countplot(x='diabetes', data=df, hue="diabetes", palette='viridis')
plt.title('Jumlah Penderita Diabetes')
plt.xlabel('Diabetes (0 = Tidak, 1 = Ya)')
plt.ylabel('Jumlah Orang')
plt.xticks(rotation=0)
plt.show()

# %% [markdown]
# ## **Line Chart**

# %%
df_visits_per_day = df.groupby('smoking_history').size()
plt.figure(figsize=(10, 5))
plt.plot(df_visits_per_day.index, df_visits_per_day.values, marker='o', color='purple')
plt.title('Tren Jumlah Riwayat Merokok')
plt.xlabel('Riwayat Merokok')
plt.ylabel('Jumlah Responden')
plt.grid()
plt.show()

# %% [markdown]
# ## **Pie Chart**

# %%
plt.figure(figsize=(6, 6))
df.groupby("smoking_history")["diabetes"].sum().plot(kind="pie", autopct="%1.1f%%")
plt.title('Riwayat Merokok Pada Penderita Diabetes')
plt.ylabel('')
plt.show()

# %% [markdown]
# ## **Histogram**

# %%
plt.figure(figsize=(8, 5))
sns.histplot(df['blood_glucose_level'], bins=20, kde=True, color='blue')
plt.title('Kadar Glukosa Darah Pada Penderita Diabates')
plt.xlabel('Kadar Glukosa Darah')
plt.ylabel('Frekuensi')
plt.show()

# %% [markdown]
# ## **Scatter Plot**

# %%
plt.figure(figsize=(8, 5))
sns.scatterplot(x='gender', y='age', hue='diabetes', data=df)
plt.title('Kadar Glukosa Darah vs Usia')
plt.xlabel('Kadar Glukosa Darah (0 = Tidak, 1 = Ya)')
plt.ylabel('Usia')
plt.legend(title='Diabetes')
plt.show()

# %%
plt.figure(figsize=(8, 5))
sns.barplot(x='blood_glucose_level', y='age', data=df, palette='pastel')
plt.title('Total Kadar Glukosa Berdasarkan Usia')
plt.xlabel('Kadar Glukosa')
plt.ylabel('Usia')
plt.xticks(rotation=0)
plt.show()
# Out:
# <ipython-input-39-5ed858dd9763>:2: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.barplot(x='blood_glucose_level', y='age', data=df, palette='pastel')

# %% [markdown]
# ## **Box Plot**

# %%
plt.figure(figsize=(8, 5))
sns.boxplot(x=df["heart_disease"], y=df["age"], palette="Set2")
plt.title("Distribusi Penyakit jantung Berdasarkan Usia")
plt.xlabel("Penyakit Jantung")
plt.ylabel("Usia")
plt.show()
# Out:
# <ipython-input-40-d07ff2fb951b>:2: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.boxplot(x=df["heart_disease"], y=df["age"], palette="Set2")

# %% [markdown]
# # **INSIGHT DAN TINDAKAN**

# %% [markdown]
# Berdasarkan dataset yang telah dianalisis, terdapat insight diantaranya yaitu:
#
# - Berdasarkan bar chart yang menunjukkan jumlah penderita diabetes (0 = Tidak, 1 = Ya) dari dataset, terdapat beberapa tindakan yang dapat diambil untuk meningkatkan kesehatan masyarakat. Pertama, meningkatkan kesadaran masyarakat tentang diabetes, faktor risikonya, dan pentingnya deteksi dini. Kampanye informasi di komunitas, sekolah, dan tempat kerja dapat menjadi langkah awal yang efektif.
# - Berdasarkan line chart yang menunjukkan tren jumlah riwayat merokok dari dataset, terdapat beberapa tindakan yang dapat diambil untuk meningkatkan kesehatan masyarakat dan mengurangi prevalensi merokok. Pertama, jika chart menunjukkan bahwa ada proporsi responden yang signifikan dengan riwayat merokok, penting untuk meningkatkan kesadaran tentang bahaya merokok dan dampaknya terhadap kesehatan.
# - Berdasarkan pie chart yang menunjukkan riwayat merokok pada penderita diabetes, kita dapat melakukan tindakan yang relevan untuk meningkatkan kesehatan masyarakat. Oleh karena itu, penting untuk meningkatkan kesadaran tentang risiko kesehatan yang lebih tinggi bagi penderita diabetes yang merokok, serta mengedukasi mereka tentang bagaimana merokok dapat memperburuk kondisi diabetes dan meningkatkan risiko komplikasi.
# - Berdasarkan histogram yang menunjukkan kadar glukosa darah pada penderita diabetes, kita dapat melakukan tindakan yang relevan untuk meningkatkan pemahaman dan pengelolaan diabetes. Histogram ini memberikan gambaran visual tentang distribusi kadar glukosa darah, termasuk frekuensi kadar glukosa dalam rentang tertentu, serta pola yang mungkin menunjukkan adanya kelompok dengan kadar glukosa yang lebih tinggi atau lebih rendah.
# - Berdasarkan scatter plot yang menunjukkan hubungan antara jenis kelamin, usia, dan status diabetes, kita dapat mengembangkan program edukasi yang ditargetkan untuk kelompok usia yang menunjukkan prevalensi diabetes lebih tinggi. Misalnya, jika individu yang lebih tua cenderung memiliki status diabetes yang lebih tinggi, program yang fokus pada pentingnya pemeriksaan kesehatan rutin, pengelolaan pola makan, dan aktivitas fisik dapat dilaksanakan.
# - Berdasarkan box plot yang menunjukkan distribusi penyakit jantung berdasarkan usia, box plot menunjukkan bahwa individu dengan penyakit jantung cenderung lebih tua, penting untuk mengidentifikasi kelompok usia yang berisiko tinggi dan memfokuskan program pencegahan serta skrining pada kelompok ini. Misalnya, mengadakan program skrining kesehatan jantung di komunitas untuk individu di atas usia tertentu, seperti 40 tahun, dapat menjadi langkah awal yang efektif.
